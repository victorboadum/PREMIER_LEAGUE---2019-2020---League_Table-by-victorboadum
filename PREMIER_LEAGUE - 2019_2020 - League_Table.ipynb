# %% [markdown]
# # PREMIER_LEAGUE - 2019/2020 - League_Table: by @victorboadum:

# %% [markdown]
# -----------------------------------------

# %%
data = [['Manchester Utd', 'Chelsea', 1, 0, 4, 0] ,
['Leicester', 'Wolves', 0, 0, 0, 0] ,
['Newcastle', 'Arsenal', 0, 0, 0, 1] ,
['Tottenham', 'Aston Villa', 0, 1, 3, 1] ,
['Bournemouth', 'Sheffield Utd', 0, 0, 1, 1] ,
['Burnley', 'Southampton', 0, 0, 3, 0] ,
['Crystal Palace', 'Everton', 0, 0, 0, 0] ,
['Watford', 'Brighton', 0, 1, 0, 3] ,
['West Ham', 'Manchester City', 0, 1, 0, 5] ,
['Liverpool', 'Norwich', 4, 0, 4, 1] ,
['Wolves', 'Manchester Utd', 0, 1, 1, 1] ,
['Chelsea', 'Leicester', 1, 0, 1, 1] ,
['Sheffield Utd', 'Crystal Palace', 0, 0, 1, 0] ,
['Manchester City', 'Tottenham', 2, 1, 2, 2] ,
['Aston Villa', 'Bournemouth', 0, 2, 1, 2] ,
['Brighton', 'West Ham', 0, 0, 1, 1] ,
['Everton', 'Watford', 1, 0, 1, 0] ,
['Norwich', 'Newcastle', 1, 0, 3, 1] ,
['Southampton', 'Liverpool', 0, 1, 1, 2] ,
['Arsenal', 'Burnley', 1, 1, 2, 1] ,
['Tottenham', 'Newcastle', 0, 1, 0, 1] ,
['Wolves', 'Burnley', 0, 1, 1, 1] ,
['Bournemouth', 'Manchester City', 1, 2, 1, 3] ,
['Liverpool', 'Arsenal', 1, 0, 3, 1] ,
['Brighton', 'Southampton', 0, 0, 0, 2] ,
['Manchester Utd', 'Crystal Palace', 0, 1, 1, 2] ,
['Sheffield Utd', 'Leicester', 0, 1, 1, 2] ,
['Watford', 'West Ham', 1, 1, 1, 3] ,
['Norwich', 'Chelsea', 2, 2, 2, 3] ,
['Aston Villa', 'Everton', 1, 0, 2, 0] ,
['Arsenal', 'Tottenham', 1, 2, 2, 2] ,
['Everton', 'Wolves', 2, 1, 3, 2] ,
['Burnley', 'Liverpool', 0, 2, 0, 3] ,
['Chelsea', 'Sheffield Utd', 2, 0, 2, 2] ,
['Crystal Palace', 'Aston Villa', 0, 0, 1, 0] ,
['Leicester', 'Bournemouth', 2, 1, 3, 1] ,
['Manchester City', 'Brighton', 2, 0, 4, 0] ,
['Newcastle', 'Watford', 1, 1, 1, 1] ,
['West Ham', 'Norwich', 1, 0, 2, 0] ,
['Southampton', 'Manchester Utd', 0, 1, 1, 1] ,
['Aston Villa', 'West Ham', 0, 0, 0, 0] ,
['Watford', 'Arsenal', 0, 2, 2, 2] ,
['Bournemouth', 'Everton', 1, 1, 3, 1] ,
['Norwich', 'Manchester City', 2, 1, 3, 2] ,
['Brighton', 'Burnley', 0, 0, 1, 1] ,
['Manchester Utd', 'Leicester', 1, 0, 1, 0] ,
['Sheffield Utd', 'Southampton', 0, 0, 0, 1] ,
['Tottenham', 'Crystal Palace', 4, 0, 4, 0] ,
['Wolves', 'Chelsea', 0, 3, 2, 5] ,
['Newcastle', 'Tottenham', 0, 1, 1, 3] ,
['Chelsea', 'Norwich', 1, 0, 1, 0] ,
['Liverpool', 'Chelsea', 3, 1, 5, 3] ,
['Manchester Utd', 'West Ham', 0, 1, 1, 1] ,
['Aston Villa', 'Arsenal', 1, 0, 1, 0] ,
['Watford', 'Manchester City', 0, 2, 0, 4] ,
['Wolves', 'Crystal Palace', 1, 0, 2, 0] ,
['Brighton', 'Newcastle', 0, 0, 0, 0] ,
['Sheffield Utd', 'Everton', 0, 0, 0, 1] ,
['Tottenham', 'Leicester', 3, 0, 3, 0] ,
['Bournemouth', 'Southampton', 0, 1, 0, 2] ,
['Norwich', 'Burnley', 0, 1, 0, 2] ,
['Arsenal', 'Watford', 3, 1, 3, 2] ,
['Burnley', 'Brighton', 1, 1, 1, 2] ,
['Chelsea', 'Wolves', 2, 0, 2, 0] ,
['Crystal Palace', 'Tottenham', 0, 1, 1, 1] ,
['Everton', 'Bournemouth', 1, 2, 1, 3] ,
['Leicester', 'Manchester Utd', 0, 0, 0, 2] ,
['Manchester City', 'Norwich', 2, 0, 5, 0] ,
['Newcastle', 'Liverpool', 1, 1, 1, 3] ,
['Southampton', 'Sheffield Utd', 0, 1, 3, 1] ,
['West Ham', 'Aston Villa', 0, 0, 1, 1]]




match_days_list = [[]] # contains 38 appended rounds of matches by 10_teams

for match in data:

    if len(match_days_list[-1]) == 10: # 10_matches per round
        match_days_list += [[]]

    match_days_list[-1] += [match]
    

data = match_days_list # pass 38 rounds of matches into data_variable

# %%
print(len(data[0]), ": matches per each round: {} times".format(len(data)))
# Out:
# 10 : matches per each round: 38 times

# %%
# league_table's features:
features = {
    "teams_position" : None,
    "teams_name" : None,
    "no_of_games_played" : 0,
    "no_of_wins" : 0,
    "no_of_draws" : 0,
    "no_of_loss" : 0,
    "goals_for_team" : 0,
    "goals_against_team" : 0,
    "goal_difference" : 0,
    "teams_total_points" : 0,
    "5_previous_scores_1" : 0,
    "5_previous_scores_2" : 0,
    "5_previous_scores_3" : 0,
    "5_previous_scores_4" : 0,
    "5_previous_scores_5" : 0,
    "5_previous_scores_6" : 0,
    "5_previous_scores_7" : 0,
    "5_previous_scores_8" : 0,
    "5_previous_scores_9" : 0,
    "5_previous_scores_10" : 0,
    "5_previous_scores_total" : 0,
    "5_previous_forms_1" : 0,
    "5_previous_forms_2" : 0,
    "5_previous_forms_3" : 0,
    "5_previous_forms_4" : 0,
    "5_previous_forms_5" : 0,
    "5_previous_forms_total" : 0 }


# expected match results:
results = {

 "home_half_time_score": 0,
 "away_half_time_score": 0,
 "home_full_time_score": 0,
 "away_full_time_score": 0,
 "half_time_total_score": 0,
 "full_time_total_score": 0,
 "half_time_draw_match": 0,
 "full_time_match_leader": 0,
 "over/under_1.5": 0,
 "over/under_2.5": 0,
 "over/under_3.5": 0
}


# teams in the 2019/2020 premier_league:
team_list = ['Manchester Utd',
 'Chelsea',
 'Leicester',
 'Wolves',
 'Newcastle',
 'Arsenal',
 'Tottenham',
 'Aston Villa',
 'Bournemouth',
 'Sheffield Utd',
 'Burnley',
 'Southampton',
 'Crystal Palace',
 'Everton',
 'Watford',
 'Brighton',
 'West Ham',
 'Manchester City',
 'Liverpool',
 'Norwich']


# statistical track_record of each team
statistics = {'Manchester Utd': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Chelsea': {'teams_position': None, 'teams_name': None,
                            'no_of_games_played': 0, 'no_of_wins': 0,
                            'no_of_draws': 0, 'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Leicester': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Wolves': {'teams_position': None,
                               'teams_name': None,
                               'no_of_games_played': 0,
                               'no_of_wins': 0,
                               'no_of_draws': 0,
                               'no_of_loss': 0,
                               'goals_for_team': 0,
                               'goals_against_team': 0,
                               'goal_difference': 0,
                               'teams_total_points': 0,
                               '5_previous_scores_1': 0,
                               '5_previous_scores_2': 0,
                               '5_previous_scores_3': 0,
                               '5_previous_scores_4': 0,
                               '5_previous_scores_5': 0,
                               '5_previous_scores_6': 0,
                               '5_previous_scores_7': 0,
                               '5_previous_scores_8': 0,
                               '5_previous_scores_9': 0,
                               '5_previous_scores_10': 0,
                               '5_previous_scores_total': 0,
                               '5_previous_forms_1': 0,
                               '5_previous_forms_2': 0,
                               '5_previous_forms_3': 0,
                               '5_previous_forms_4': 0,
                               '5_previous_forms_5': 0,
                               '5_previous_forms_total': 0},
              'Newcastle': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Arsenal': {'teams_position': None,
                           'teams_name': None,
                           'no_of_games_played': 0,
                           'no_of_wins': 0,
                           'no_of_draws': 0,
                           'no_of_loss': 0,
                           'goals_for_team': 0,
                           'goals_against_team': 0,
                           'goal_difference': 0,
                           'teams_total_points': 0,
                           '5_previous_scores_1': 0,
                           '5_previous_scores_2': 0,
                           '5_previous_scores_3': 0,
                           '5_previous_scores_4': 0,
                           '5_previous_scores_5': 0,
                           '5_previous_scores_6': 0,
                           '5_previous_scores_7': 0,
                           '5_previous_scores_8': 0,
                           '5_previous_scores_9': 0,
                           '5_previous_scores_10': 0,
                           '5_previous_scores_total': 0,
                           '5_previous_forms_1': 0,
                           '5_previous_forms_2': 0,
                           '5_previous_forms_3': 0,
                           '5_previous_forms_4': 0,
                           '5_previous_forms_5': 0,
                           '5_previous_forms_total': 0},
              'Tottenham': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Aston Villa': {'teams_position': None,
                                'teams_name': None,
                                'no_of_games_played': 0,
                                'no_of_wins': 0,
                                'no_of_draws': 0,
                                'no_of_loss': 0,
                                'goals_for_team': 0,
                                'goals_against_team': 0,
                                'goal_difference': 0,
                                'teams_total_points': 0,
                                '5_previous_scores_1': 0,
                                '5_previous_scores_2': 0,
                                '5_previous_scores_3': 0,
                                '5_previous_scores_4': 0,
                                '5_previous_scores_5': 0,
                                '5_previous_scores_6': 0,
                                '5_previous_scores_7': 0,
                                '5_previous_scores_8': 0,
                                '5_previous_scores_9': 0,
                                '5_previous_scores_10': 0,
                                '5_previous_scores_total': 0,
                                '5_previous_forms_1': 0,
                                '5_previous_forms_2': 0,
                                '5_previous_forms_3': 0,
                                '5_previous_forms_4': 0,
                                '5_previous_forms_5': 0,
                                '5_previous_forms_total': 0},
              'Bournemouth': {'teams_position': None,
                          'teams_name': None,
                          'no_of_games_played': 0,
                          'no_of_wins': 0,
                          'no_of_draws': 0,
                          'no_of_loss': 0,
                          'goals_for_team': 0,
                          'goals_against_team': 0,
                          'goal_difference': 0,
                          'teams_total_points': 0,
                          '5_previous_scores_1': 0,
                          '5_previous_scores_2': 0,
                          '5_previous_scores_3': 0,
                          '5_previous_scores_4': 0,
                          '5_previous_scores_5': 0,
                          '5_previous_scores_6': 0,
                          '5_previous_scores_7': 0,
                          '5_previous_scores_8': 0,
                          '5_previous_scores_9': 0,
                          '5_previous_scores_10': 0,
                          '5_previous_scores_total': 0,
                          '5_previous_forms_1': 0,
                          '5_previous_forms_2': 0,
                          '5_previous_forms_3': 0,
                          '5_previous_forms_4': 0,
                          '5_previous_forms_5': 0,
                          '5_previous_forms_total': 0},
              'Sheffield Utd': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Burnley': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Southampton': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Crystal Palace': {'teams_position': None,
                          'teams_name': None,
                          'no_of_games_played': 0,
                          'no_of_wins': 0,
                          'no_of_draws': 0,
                          'no_of_loss': 0,
                          'goals_for_team': 0,
                          'goals_against_team': 0,
                          'goal_difference': 0,
                          'teams_total_points': 0,
                          '5_previous_scores_1': 0,
                          '5_previous_scores_2': 0,
                          '5_previous_scores_3': 0,
                          '5_previous_scores_4': 0,
                          '5_previous_scores_5': 0,
                          '5_previous_scores_6': 0,
                          '5_previous_scores_7': 0,
                          '5_previous_scores_8': 0,
                          '5_previous_scores_9': 0,
                          '5_previous_scores_10': 0,
                          '5_previous_scores_total': 0,
                          '5_previous_forms_1': 0,
                          '5_previous_forms_2': 0,
                          '5_previous_forms_3': 0,
                          '5_previous_forms_4': 0,
                          '5_previous_forms_5': 0,
                          '5_previous_forms_total': 0},
              'Everton': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Watford': {'teams_position': None,
                          'teams_name': None,
                          'no_of_games_played': 0,
                          'no_of_wins': 0,
                          'no_of_draws': 0,
                          'no_of_loss': 0,
                          'goals_for_team': 0,
                          'goals_against_team': 0,
                          'goal_difference': 0,
                          'teams_total_points': 0,
                          '5_previous_scores_1': 0,
                          '5_previous_scores_2': 0,
                          '5_previous_scores_3': 0,
                          '5_previous_scores_4': 0,
                          '5_previous_scores_5': 0,
                          '5_previous_scores_6': 0,
                          '5_previous_scores_7': 0,
                          '5_previous_scores_8': 0,
                          '5_previous_scores_9': 0,
                          '5_previous_scores_10': 0,
                          '5_previous_scores_total': 0,
                          '5_previous_forms_1': 0,
                          '5_previous_forms_2': 0,
                          '5_previous_forms_3': 0,
                          '5_previous_forms_4': 0,
                          '5_previous_forms_5': 0,
                          '5_previous_forms_total': 0},
              'Brighton': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'West Ham': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Manchester City': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Liverpool': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0},
              'Norwich': {'teams_position': None,
                            'teams_name': None,
                            'no_of_games_played': 0,
                            'no_of_wins': 0,
                            'no_of_draws': 0,
                            'no_of_loss': 0,
                            'goals_for_team': 0,
                            'goals_against_team': 0,
                            'goal_difference': 0,
                            'teams_total_points': 0,
                            '5_previous_scores_1': 0,
                            '5_previous_scores_2': 0,
                            '5_previous_scores_3': 0,
                            '5_previous_scores_4': 0,
                            '5_previous_scores_5': 0,
                            '5_previous_scores_6': 0,
                            '5_previous_scores_7': 0,
                            '5_previous_scores_8': 0,
                            '5_previous_scores_9': 0,
                            '5_previous_scores_10': 0,
                            '5_previous_scores_total': 0,
                            '5_previous_forms_1': 0,
                            '5_previous_forms_2': 0,
                            '5_previous_forms_3': 0,
                            '5_previous_forms_4': 0,
                            '5_previous_forms_5': 0,
                            '5_previous_forms_total': 0}}

# %%
# LEAGUE_TABLE FEATURE_FUNCTIONS:

# a = home_team
# b = away_team
# c = home_team_half_time_score
# d = away_team_half_time_score
# e = home_team_full_time_score
# f = away_team_full_time_score

#######################################################
def teams_name_for_a(a): # track the names of teams in play:
    global statistics
    statistics[a]['teams_name'] = a
    # print("done with teams_name_a!!!")


def teams_name_for_b(b):
    global statistics
    statistics[b]['teams_name'] = b
    # print("done with teams_name_b!!!")
###########################################################

def no_of_wins_for_a(a, e, f): # track the wins of teams in play:
    global statistics

    track_no_of_wins_for_a = 0

    if e > f:
        track_no_of_wins_for_a += 1

        statistics[a]['no_of_wins'] += track_no_of_wins_for_a
        # print("done with no_of_wins_for_a!!!")


def no_of_wins_for_b(b, e, f):
    global statistics

    track_no_of_wins_for_b = 0

    if f > e:
        track_no_of_wins_for_b += 1

        statistics[b]['no_of_wins'] += track_no_of_wins_for_b
        # print("done with no_of_wins_for_b!!!")

###################################################


def no_of_draws_for_a(a, e, f): # track the draws of teams in play
    global statistics

    track_no_of_draws_for_a = 0
    if e == f:
        track_no_of_draws_for_a += 1

        statistics[a]['no_of_draws'] += track_no_of_draws_for_a
        # print("done with no_of_draws_for_a!!!")


def no_of_draws_for_b(b, e, f):
    global statistics

    track_no_of_draws_for_b = 0
    if f == e:
        track_no_of_draws_for_b += 1

        statistics[b]['no_of_draws'] += track_no_of_draws_for_b
        # print("done with no_of_draws_for_b!!!")


###########################################


def no_of_loss_for_a(a, e, f): # track the loss of teams in play
    global statistics

    track_no_of_loss_for_a = 0
    if e < f:
        track_no_of_loss_for_a += 1

        statistics[a]['no_of_loss'] += track_no_of_loss_for_a
        # print("done with no_of_loss_for_a!!!")


def no_of_loss_for_b(b, e, f):
    global statistics

    track_no_of_loss_for_b = 0
    if f < e:
        track_no_of_loss_for_b += 1

        statistics[b]['no_of_loss'] += track_no_of_loss_for_b
        # print("done with no_of_loss_for_b!!!")


############################################


def goals_for_team_for_a(a, e): # track number of goals scored by teams in play
    global statistics

    track_goals_for_team_for_a = 0
    track_goals_for_team_for_a += e

    statistics[a]['goals_for_team'] += track_goals_for_team_for_a
    # print("done with goals_for_team_for_a!!!")


def goals_for_team_for_b(b, f):
    global statistics

    track_goals_for_team_for_b = 0
    track_goals_for_team_for_b += f

    statistics[b]['goals_for_team'] += track_goals_for_team_for_b
    # print("done with goals_for_team_for_b!!!")



####################################


def goals_against_team_for_a(a, f): # track goals against teams in play:
    global statistics

    track_goals_against_team_for_a = 0
    track_goals_against_team_for_a += f

    statistics[a]['goals_against_team'] += track_goals_against_team_for_a
    # print("done with goals_against_team_for_a!!!")


def goals_against_team_for_b(b, e):
    global statistics

    track_goals_against_team_for_b = 0
    track_goals_against_team_for_b += e

    statistics[b]['goals_against_team'] += track_goals_against_team_for_b
    # print("done with goals_against_team_for_b!!!")



##########################################


def goal_difference_for_a(a): # track the goal_difference for teams in play:
    global statistics

    track_goal_difference_for_a = 0
    track_goal_difference_for_a = statistics[a]['goals_for_team'] - statistics[a]['goals_against_team']

    statistics[a]['goal_difference'] = track_goal_difference_for_a
    # print("done with goal_difference_for_a!!!")


def goal_difference_for_b(b):
    global statistics

    track_goal_difference_for_b = 0
    track_goal_difference_for_b = statistics[b]['goals_for_team'] - statistics[b]['goals_against_team']

    statistics[b]['goal_difference'] = track_goal_difference_for_b
    # print("done with goal_difference_for_b!!!")


############################################


def teams_total_points_for_a(a, e, f): # track the total_points for teams in play:
    global statistics

    track_teams_total_points_for_a = 0
    if e > f:
        track_teams_total_points_for_a += 3
    elif e == f:
        track_teams_total_points_for_a += 1
    elif e < f:
        track_teams_total_points_for_a += 0

    statistics[a]['teams_total_points'] += track_teams_total_points_for_a
    # print("done with teams_total_points_for_a!!!")


def teams_total_points_for_b(b, e, f):
    global statistics

    track_teams_total_points_for_b = 0
    if f > e:
        track_teams_total_points_for_b += 3
    elif f == e:
        track_teams_total_points_for_b += 1
    elif f < e:
        track_teams_total_points_for_b += 0

    statistics[b]['teams_total_points'] += track_teams_total_points_for_b
    # print("done with teams_total_points_for_b!!!")


##################################


def previous_5_scores_for_a(a, e, f): # track the last five individual_scores of teams in play: 
    global statistics

    # rotate scores to take out old scores
    statistics[a]['5_previous_scores_1'], statistics[a]['5_previous_scores_2'], statistics[a]['5_previous_scores_3'], statistics[a]['5_previous_scores_4'], statistics[a]['5_previous_scores_5'], statistics[a]['5_previous_scores_6'], statistics[a]['5_previous_scores_7'], statistics[a]['5_previous_scores_8'] = statistics[a]['5_previous_scores_3'], statistics[a]['5_previous_scores_4'], statistics[a]['5_previous_scores_5'], statistics[a]['5_previous_scores_6'], statistics[a]['5_previous_scores_7'], statistics[a]['5_previous_scores_8'], statistics[a]['5_previous_scores_9'], statistics[a]['5_previous_scores_10']

    # assign new scores to old score taken out
    statistics[a]['5_previous_scores_9'], statistics[a]['5_previous_scores_10'] = e , f



def previous_5_scores_for_b(b, e, f):
    global statistics

    # 1,2,3,4,5,6,7,8 = 3,4,5,6,7,8,9,10

    # rotate scores to take out old scores
    statistics[b]['5_previous_scores_1'], statistics[b]['5_previous_scores_2'], statistics[b]['5_previous_scores_3'], \
    statistics[b]['5_previous_scores_4'], statistics[b]['5_previous_scores_5'], statistics[b]['5_previous_scores_6'], \
    statistics[b]['5_previous_scores_7'], statistics[b]['5_previous_scores_8'] = statistics[b]['5_previous_scores_3'], \
                                                                                 statistics[b]['5_previous_scores_4'], \
                                                                                 statistics[b]['5_previous_scores_5'], \
                                                                                 statistics[b]['5_previous_scores_6'], \
                                                                                 statistics[b]['5_previous_scores_7'], \
                                                                                 statistics[b]['5_previous_scores_8'], \
                                                                                 statistics[b]['5_previous_scores_9'], \
                                                                                 statistics[b]['5_previous_scores_10']

    # assign new scores after the old scores had being taken out
    statistics[b]['5_previous_scores_9'], statistics[b]['5_previous_scores_10'] = e, f

    # print("done with 5_previous_scores_for_b!!!")


###########################################



def previous_5_scores_total_for_a(a): # track the total of the 5_previous scores of teams in play:
    global statistics

    statistics[a]['5_previous_scores_total'] = statistics[a]['5_previous_scores_1'] + statistics[a]['5_previous_scores_2'] + statistics[a]['5_previous_scores_3'] + statistics[a]['5_previous_scores_4'] + statistics[a]['5_previous_scores_5'] + statistics[a]['5_previous_scores_6'] + statistics[a]['5_previous_scores_7'] + statistics[a]['5_previous_scores_8'] + statistics[a]['5_previous_scores_9'] + statistics[a]['5_previous_scores_10']

    # print("done with 5_previous_scores_total_for_a!!!")


def previous_5_scores_total_for_b(b):
    global statistics

    statistics[b]['5_previous_scores_total'] = statistics[b]['5_previous_scores_1'] + statistics[b][
        '5_previous_scores_2'] + statistics[b]['5_previous_scores_3'] + statistics[b]['5_previous_scores_4'] + \
                                               statistics[b]['5_previous_scores_5'] + statistics[b][
                                                   '5_previous_scores_6'] + statistics[b]['5_previous_scores_7'] + \
                                               statistics[b]['5_previous_scores_8'] + statistics[b][
                                                   '5_previous_scores_9'] + statistics[b]['5_previous_scores_10']


############################################


def previous_5_forms_for_a(a, e, f): # track the 5_previous scores of teams in play:
    global statistics

    # 1,2,3,4 = 2,3,4,5

    statistics[a]['5_previous_forms_1'], statistics[a]['5_previous_forms_2'], statistics[a]['5_previous_forms_3'], statistics[a]['5_previous_forms_4'] = statistics[a]['5_previous_forms_2'], statistics[a]['5_previous_forms_3'], statistics[a]['5_previous_forms_4'], statistics[a]['5_previous_forms_5']

    if e > f:
        statistics[a]['5_previous_forms_5'] = 'W'   #20
    elif e == f:
        statistics[a]['5_previous_forms_5'] = 'D'  #10
    elif e < f:
        statistics[a]['5_previous_forms_5'] = 'L'   #0

    #statistics[a]['5_previous_forms'] += track_previous_5_forms_for_a
    # print("done with 5_previous_forms_for_a!!!")


def previous_5_forms_for_b(b, e, f):
    global statistics

    statistics[b]['5_previous_forms_1'], statistics[b]['5_previous_forms_2'], statistics[b]['5_previous_forms_3'], \
    statistics[b]['5_previous_forms_4'] = statistics[b]['5_previous_forms_2'], statistics[b]['5_previous_forms_3'], \
                                          statistics[b]['5_previous_forms_4'], statistics[b]['5_previous_forms_5']

    if f > e:
        statistics[b]['5_previous_forms_5'] = 'W'  #20
    elif f == e:
        statistics[b]['5_previous_forms_5'] = 'D'  #10
    elif f < e:
        statistics[b]['5_previous_forms_5'] = 'L'  #0

    #statistics[b]['5_previous_forms'] += track_previous_5_forms_for_b
    # print("done with 5_previous_forms_for_b!!!")

##################################################



def previous_5_forms_total_for_a(a): # track the total_forms of teams in play:
    global statistics

    # track_previous_5_forms_total_for_a = 0
    #
    # for score in statistics[a]['5_previous_forms']:
    #     track_previous_5_forms_total_for_a += score

    statistics[a]['5_previous_forms_total'] = statistics[a]['5_previous_forms_1'] + statistics[a]['5_previous_forms_2'] + statistics[a]['5_previous_forms_3'] + statistics[a]['5_previous_forms_4']  + statistics[a]['5_previous_forms_5']

    # print("done with 5_previous_forms_total_for_a!!!")


def previous_5_forms_total_for_b(b):
    global statistics

    # track_previous_5_forms_total_for_b = 0
    #
    # for score in statistics[b]['5_previous_forms']:
    #     track_previous_5_forms_total_for_b += score

    statistics[b]['5_previous_forms_total'] = statistics[b]['5_previous_forms_1'] + statistics[b]['5_previous_forms_2'] + statistics[b]['5_previous_forms_3'] + statistics[b]['5_previous_forms_4']  + statistics[b]['5_previous_forms_5']

    # print("done with 5_previous_forms_total_for_b!!!")




####################################

# TEAMS_POSITION:

league_table = []


def teams_position(a, b, c, d, e, f): # place teams in position according to their performance
    global statistics, league_table
    
    ########################################

    teams_name_list = []
    teams_total_points_list = [] 

    for team in statistics: # track teams_position by the value of the points they have:
        teams_name_list += [team]
        teams_total_points_list += [statistics[team]['teams_total_points']]
    # print("done")
    
    ########################################

    total_points_dict = {}

    for index in range(len(teams_total_points_list)): # track into a dictionary: teams_name & their respective points
        total_points_dict[teams_name_list[index]] = teams_total_points_list[index]
        # print("done")

        
    #######################################
    
    for point in teams_total_points_list: # oder the points of the teams from large to small
        for index in range(len(teams_total_points_list) - 1):
            if teams_total_points_list[index] < teams_total_points_list[index + 1]:
                teams_total_points_list[index], teams_total_points_list[index + 1] = teams_total_points_list[index + 1], \
                                                                                     teams_total_points_list[index]
    # print("done")

    teams_position_points = teams_total_points_list  # ordered: big to low
    
    #######################################

    team_position_names = []  

    for point in teams_position_points: # pass into a list: unique names of teams
        for team_name in total_points_dict:
            if team_name not in team_position_names:
                if total_points_dict[team_name] == point:
                    team_position_names += [team_name]
    # print("done")
    
    #######################################

    # team_position_names = ["e", "c", "b", "a", "d", "f"]
    # teams_position_points = [5, 5, 5, 3, 2, 1]
    for i in range(len(teams_position_points) - 2): # suppose 3_teams share the same points, 
                                                    # track positions by their goal_difference

        if teams_position_points[i] == teams_position_points[i + 1] and teams_position_points[i] == \
                teams_position_points[i + 2]:
            if statistics[team_position_names[i]]['goal_difference'] < statistics[team_position_names[i + 1]][
                'goal_difference'] and statistics[team_position_names[i]]['goal_difference'] < \
                    statistics[team_position_names[i + 2]]['goal_difference'] and \
                    statistics[team_position_names[i + 1]]['goal_difference'] > statistics[team_position_names[i + 2]][
                'goal_difference']:
                team_position_names[i], team_position_names[i + 1], team_position_names[i + 2] = team_position_names[i], \
                                                                                                 team_position_names[
                                                                                                     i + 2], \
                                                                                                 team_position_names[
                                                                                                     i + 1]
                teams_position_points[i], teams_position_points[i + 1], teams_position_points[i + 2] = \
                teams_position_points[i], teams_position_points[i + 2], teams_position_points[i + 1]
            elif statistics[team_position_names[i]]['goal_difference'] < statistics[team_position_names[i + 1]][
                'goal_difference'] and statistics[team_position_names[i]]['goal_difference'] > \
                    statistics[team_position_names[i + 2]]['goal_difference'] and \
                    statistics[team_position_names[i + 1]]['goal_difference'] > statistics[team_position_names[i + 2]][
                'goal_difference']:
                team_position_names[i], team_position_names[i + 1], team_position_names[i + 2] = team_position_names[
                                                                                                     i + 2], \
                                                                                                 team_position_names[i], \
                                                                                                 team_position_names[
                                                                                                     i + 1]
                teams_position_points[i], teams_position_points[i + 1], teams_position_points[i + 2] = \
                teams_position_points[i + 2], teams_position_points[i], teams_position_points[i + 1]
            elif statistics[team_position_names[i]]['goal_difference'] > statistics[team_position_names[i + 1]][
                'goal_difference'] and statistics[team_position_names[i]]['goal_difference'] < \
                    statistics[team_position_names[i + 2]]['goal_difference'] and \
                    statistics[team_position_names[i + 1]]['goal_difference'] < statistics[team_position_names[i + 2]][
                'goal_difference']:
                team_position_names[i], team_position_names[i + 1], team_position_names[i + 2] = team_position_names[
                                                                                                     i + 1], \
                                                                                                 team_position_names[i], \
                                                                                                 team_position_names[
                                                                                                     i + 2]
                teams_position_points[i], teams_position_points[i + 1], teams_position_points[i + 2] = \
                teams_position_points[i + 1], teams_position_points[i], teams_position_points[i + 2]
            elif statistics[team_position_names[i]]['goal_difference'] > statistics[team_position_names[i + 1]][
                'goal_difference'] and statistics[team_position_names[i]]['goal_difference'] > \
                    statistics[team_position_names[i + 2]]['goal_difference'] and \
                    statistics[team_position_names[i + 1]]['goal_difference'] < statistics[team_position_names[i + 2]][
                'goal_difference']:
                team_position_names[i], team_position_names[i + 1], team_position_names[i + 2] = team_position_names[
                                                                                                     i + 1], \
                                                                                                 team_position_names[
                                                                                                     i + 2], \
                                                                                                 team_position_names[i]
                teams_position_points[i], teams_position_points[i + 1], teams_position_points[i + 2] = \
                teams_position_points[i + 1], teams_position_points[i + 2], teams_position_points[i]
            elif statistics[team_position_names[i]]['goal_difference'] > statistics[team_position_names[i + 1]][
                'goal_difference'] and statistics[team_position_names[i]]['goal_difference'] > \
                    statistics[team_position_names[i + 2]]['goal_difference'] and \
                    statistics[team_position_names[i + 1]]['goal_difference'] > statistics[team_position_names[i + 2]][
                'goal_difference']:
                team_position_names[i], team_position_names[i + 1], team_position_names[i + 2] = team_position_names[
                                                                                                     i + 2], \
                                                                                                 team_position_names[
                                                                                                     i + 1], \
                                                                                                 team_position_names[i]
                teams_position_points[i], teams_position_points[i + 1], teams_position_points[i + 2] = \
                teams_position_points[i + 2], teams_position_points[i + 1], teams_position_points[i]

        if teams_position_points[i] == teams_position_points[i + 1]:
            if statistics[team_position_names[i]]['goal_difference'] < statistics[team_position_names[i + 1]][
                'goal_difference']:
                team_position_names[i], team_position_names[i + 1] = team_position_names[i + 1], team_position_names[i]
                teams_position_points[i], teams_position_points[i + 1] = teams_position_points[i + 1], \
                                                                         teams_position_points[i]
    # print("done")
    
    #####################################

    # ordered postions:
    # team_position_names = ["e", "c", "b", "a", "d", "f"]
    # teams_position_points = [5, 5, 5, 3, 2, 1]: from: large to small
    track_teams_position = 0

    for index in range(len(team_position_names)): # giving teams their position by the order of index:
        track_teams_position += 1
        statistics[team_position_names[index]]['teams_position'] = track_teams_position

    #####################################

    for team_name in team_position_names: # by teams_position: a league_table is constructed
        #if len(league_table[-1]) == 14:
        league_table += [[]]
        for feature in statistics[team_name]:
            league_table[-1] += [statistics[team_name][feature]]

# %%
statistics_list = []
no_of_games_played = 0
no_of_matches_played = 0

for match_day in range(len(data)):
    no_of_games_played += 1

    # STATISTICS:
    for a, b, c, d, e, f in data[match_day]:
        no_of_matches_played += 1
        # a = home_team
        # b = away_team
        # c = home_team_half_time_score
        # d = away_team_half_time_score
        # e = home_team_full_time_score
        # f = away_team_full_time_score

        # teams in play
        teams_name_for_a(a=a)
        teams_name_for_b(b=b)

        # no. of games played:
        statistics[a]['no_of_games_played'] = no_of_games_played
        statistics[b]['no_of_games_played'] = no_of_games_played

        # updating statistics with live_match scores to predict the next_match
        no_of_wins_for_a(a=a, e=e, f=f)
        no_of_wins_for_b(b=b, e=e, f=f)
        no_of_draws_for_a(a=a, e=e, f=f)
        no_of_draws_for_b(b=b, e=e, f=f)
        no_of_loss_for_a(a=a, e=e, f=f)
        no_of_loss_for_b(b=b, e=e, f=f)
        goals_for_team_for_a(a=a, e=e)
        goals_for_team_for_b(b=b, f=f)
        goals_against_team_for_a(a=a, f=f)
        goals_against_team_for_b(b=b, e=e)
        goal_difference_for_a(a=a)
        goal_difference_for_b(b=b)
        teams_total_points_for_a(a=a, e=e, f=f)
        teams_total_points_for_b(b=b, e=e, f=f)
        previous_5_scores_for_a(a=a, e=e, f=f)
        previous_5_scores_for_b(b=b, e=e, f=f)
        previous_5_scores_total_for_a(a=a)
        previous_5_scores_total_for_b(b=b)
        previous_5_forms_for_a(a=a, e=e, f=f)
        previous_5_forms_for_b(b=b, e=e, f=f)
        #previous_5_forms_total_for_a(a=a)
        #previous_5_forms_total_for_b(b=b)

        teams_position(a = a, b = b, c = c, d = d, e = e, f = f)

# %%
# PRINT_OUT: league Table:

print("*********************************************************************************************************")
feature_list = []
for i in features:
    feature_list += [i]
    
print(feature_list)  
print("*********************************************************************************************************")

for i in league_table[-20:]:
    a = i[21]
    b = i[22]
    c = i[23]
    d = i[24]
    e = i[25]
    
    i[21] = e
    i[22] = d
    i[23] = c
    i[24] = b
    i[25] = a
    
    del i[-1]
    del i[10:21]
    
    print(i)
    
print("*********************************************************************************************************")
# Out:
# *********************************************************************************************************
# ['teams_position', 'teams_name', 'no_of_games_played', 'no_of_wins', 'no_of_draws', 'no_of_loss', 'goals_for_team', 'goals_against_team', 'goal_difference', 'teams_total_points', '5_previous_scores_1', '5_previous_scores_2', '5_previous_scores_3', '5_previous_scores_4', '5_previous_scores_5', '5_previous_scores_6', '5_previous_scores_7', '5_previous_scores_8', '5_previous_scores_9', '5_previous_scores_10', '5_previous_scores_total', '5_previous_forms_1', '5_previous_forms_2', '5_previous_forms_3', '5_previous_forms_4', '5_previous_forms_5', '5_previous_forms_total']
# *********************************************************************************************************
# [1, 'Liverpool', 38, 32, 3, 3, 85, 33, 52, 99, 'W', 'W', 'L', 'D', 'W']
# [2, 'Manchester City', 38, 26, 3, 9, 102, 35, 67, 81, 'W', 'W', 'W', 'W', 'W']
# ...
